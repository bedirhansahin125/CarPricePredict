# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sbn
import tensorflow as tsf

# %%
dataFrame=pd.read_excel("merc.xlsx")

# %%
dataFrame.head()
# Out:
#    year  price transmission  mileage  tax   mpg  engineSize
# 0  2005   5200    Automatic    63000  325  32.1         1.8
# 1  2017  34948    Automatic    27000   20  61.4         2.1
# 2  2016  49948    Automatic     6200  555  28.0         5.5
# 3  2016  61948    Automatic    16000  325  30.4         4.0
# 4  2016  73948    Automatic     4000  325  30.1         4.0

# %%
dataFrame.describe() ## understanding dataset
# Out:
#                year          price        mileage           tax           mpg  \
# count  13119.000000   13119.000000   13119.000000  13119.000000  13119.000000
# mean    2017.296288   24698.596920   21949.559037    129.972178     55.155843
# std        2.224709   11842.675542   21176.512267     65.260286     15.220082
# min     1970.000000     650.000000       1.000000      0.000000      1.100000
# 25%     2016.000000   17450.000000    6097.500000    125.000000     45.600000
# 50%     2018.000000   22480.000000   15189.000000    145.000000     56.500000
# 75%     2019.000000   28980.000000   31779.500000    145.000000     64.200000
# max     2020.000000  159999.000000  259000.000000    580.000000    217.300000
#
#          engineSize
# count  13119.000000
# mean       2.071530
# std        0.572426
# min        0.000000
# 25%        1.800000
# 50%        2.000000
# 75%        2.100000
# max        6.200000

# %%
dataFrame.isnull().sum() ##check up null row&columns
# Out:
# year            0
# price           0
# transmission    0
# mileage         0
# tax             0
# mpg             0
# engineSize      0
# dtype: int64

# %%
plt.figure(figsize=(10,8))
sbn.distplot(dataFrame["price"])        ## distribution plot of cars' price
# Out:
# C:\Users\MATEBOOK16\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
plt.figure(figsize=(10,8))
sbn.countplot(dataFrame["year"])
# Out:
# C:\Users\MATEBOOK16\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='year', ylabel='count'>

# %%
dataFrame.corr() ## dataFrame correlation
# Out:
#                 year     price   mileage       tax       mpg  engineSize
# year        1.000000  0.520712 -0.738027  0.012480 -0.094626   -0.142147
# price       0.520712  1.000000 -0.537214  0.268717 -0.438445    0.516126
# mileage    -0.738027 -0.537214  1.000000 -0.160223  0.202850    0.063652
# tax         0.012480  0.268717 -0.160223  1.000000 -0.513742    0.338341
# mpg        -0.094626 -0.438445  0.202850 -0.513742  1.000000   -0.339862
# engineSize -0.142147  0.516126  0.063652  0.338341 -0.339862    1.000000

# %%
dataFrame.corr()["price"].sort_values() ## most positive relationship is "year"
# Out:
# mileage      -0.537214
# mpg          -0.438445
# tax           0.268717
# engineSize    0.516126
# year          0.520712
# price         1.000000
# Name: price, dtype: float64

# %%
plt.figure(figsize=(10,8))
sbn.scatterplot(x="mileage",y="price",data=dataFrame)
# Out:
# <AxesSubplot:xlabel='mileage', ylabel='price'>

# %%
dataFrame.sort_values("price",ascending=False).head(20) ##ascending=False  20 higher price to up ^ table
# Out:
#        year   price transmission  mileage  tax   mpg  engineSize
# 6199   2020  159999    Semi-Auto     1350  145  21.4         4.0
# 10044  2020  154998    Automatic     3000  150  21.4         4.0
# 5      2011  149948    Automatic     3000  570  21.4         6.2
# 8737   2019  140319    Semi-Auto      785  150  22.1         4.0
# 6386   2018  139995    Semi-Auto    13046  145  21.4         4.0
# 8      2019  139948    Automatic    12000  145  21.4         4.0
# 9133   2019  139559    Semi-Auto     1000  145  22.1         4.0
# 8821   2020  138439    Semi-Auto     1000  145  22.1         4.0
# 5902   2018  135771    Semi-Auto    19000  145  21.4         4.0
# 7864   2018  135124    Semi-Auto    18234  150  21.4         4.0
# 8673   2019  134219    Semi-Auto     1000  145  24.8         4.0
# 6210   2019  129990    Automatic     1000  145  24.8         4.0
# 4759   2019  126000    Automatic      250  145  24.6         4.0
# ...

# %%
dataFrame.sort_values("price",ascending=True).head(20) ##ascending=False  20 cheaper price to up ^ table
# Out:
#        year  price transmission  mileage  tax   mpg  engineSize
# 11816  2003    650       Manual   109090  235  40.0         1.4
# 12008  2010   1350       Manual   116126  145  54.3         2.0
# 11765  2000   1490    Automatic    87000  265  27.2         3.2
# 11549  2002   1495    Automatic    13800  305  39.8         2.7
# 12594  2004   1495       Manual   119000  300  34.5         1.8
# 11174  2001   1695    Automatic   108800  325  31.7         3.2
# 12710  2006   1695    Automatic   153000  300  33.6         1.8
# 12766  2004   1780    Automatic   118000  265  41.5         2.2
# 12009  2007   1800    Automatic    84000  200  42.8         1.5
# 11764  1998   1990    Automatic    99300  265  32.1         2.3
# 11808  1998   1990    Automatic   113557  265  32.1         2.3
# 11383  2005   1995    Automatic   105000  260  43.5         2.1
# 11378  2004   1995    Semi-Auto   165000  330  20.0         3.7
# 11857  2002   2140    Automatic    52700  325  31.4         2.0
# ...

# %%
len(dataFrame) ## lenght dataFrame
# Out:
# 13119

# %%
ninetyNineDataFrame=dataFrame.sort_values("price",ascending=False).iloc[131:] ## we drop most high %0.01 data

# %%
ninetyNineDataFrame.describe()
# Out:
#                year         price        mileage           tax           mpg  \
# count  12988.000000  12988.000000   12988.000000  12988.000000  12988.000000
# mean    2017.281876  24074.926933   22132.741146    129.689714     55.437142
# std        2.228515   9866.224575   21196.776401     65.183076     15.025999
# min     1970.000000    650.000000       1.000000      0.000000      1.100000
# 25%     2016.000000  17357.500000    6322.000000    125.000000     45.600000
# 50%     2018.000000  22299.000000   15369.500000    145.000000     56.500000
# 75%     2019.000000  28706.000000   31982.250000    145.000000     64.200000
# max     2020.000000  65990.000000  259000.000000    580.000000    217.300000
#
#          engineSize
# count  12988.000000
# mean       2.050901
# std        0.532596
# min        0.000000
# 25%        1.675000
# 50%        2.000000
# 75%        2.100000
# max        6.200000

# %%
plt.figure(figsize=(10,8))
sbn.distplot(ninetyNineDataFrame["price"])
# Out:
# C:\Users\MATEBOOK16\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
dataFrame.groupby("year").mean()["price"]
# Out:
# year
# 1970    24999.000000
# 1997     9995.000000
# 1998     8605.000000
# 1999     5995.000000
# 2000     5743.333333
# 2001     4957.900000
# 2002     5820.444444
# 2003     4878.000000
# 2004     4727.615385
# 2005     4426.111111
# 2006     4036.875000
# 2007     5136.045455
# 2008     6967.437500
# 2009     6166.764706
# 2010     8308.473684
# 2011    12624.894737
# 2012    10845.140351
# 2013    11939.842466
# 2014    14042.936864
# 2015    16731.780020
# 2016    19307.892948
# 2017    21514.307854
# 2018    25720.162918
# 2019    31290.020865
# 2020    35433.282337
# Name: price, dtype: float64

# %%
ninetyNineDataFrame.groupby("year").mean()["price"]
# Out:
# year
# 1970    24999.000000
# 1997     9995.000000
# 1998     8605.000000
# 1999     5995.000000
# 2000     5743.333333
# 2001     4957.900000
# 2002     5820.444444
# 2003     4878.000000
# 2004     4727.615385
# 2005     4426.111111
# 2006     4036.875000
# 2007     5136.045455
# 2008     6967.437500
# 2009     6166.764706
# 2010     8308.473684
# 2011     8913.459459
# 2012    10845.140351
# 2013    11939.842466
# 2014    14042.936864
# 2015    16647.822222
# 2016    19223.558943
# 2017    21356.280421
# 2018    24800.844506
# 2019    30289.524832
# 2020    34234.794872
# Name: price, dtype: float64

# %%
dataFrame[dataFrame.year != 1970].groupby("year").mean()["price"]
# Out:
# year
# 1997     9995.000000
# 1998     8605.000000
# 1999     5995.000000
# 2000     5743.333333
# 2001     4957.900000
# 2002     5820.444444
# 2003     4878.000000
# 2004     4727.615385
# 2005     4426.111111
# 2006     4036.875000
# 2007     5136.045455
# 2008     6967.437500
# 2009     6166.764706
# 2010     8308.473684
# 2011    12624.894737
# 2012    10845.140351
# 2013    11939.842466
# 2014    14042.936864
# 2015    16731.780020
# 2016    19307.892948
# 2017    21514.307854
# 2018    25720.162918
# 2019    31290.020865
# 2020    35433.282337
# Name: price, dtype: float64

# %%
dataFrame=ninetyNineDataFrame

# %%
dataFrame.describe()
# Out:
#                year         price        mileage           tax           mpg  \
# count  12988.000000  12988.000000   12988.000000  12988.000000  12988.000000
# mean    2017.281876  24074.926933   22132.741146    129.689714     55.437142
# std        2.228515   9866.224575   21196.776401     65.183076     15.025999
# min     1970.000000    650.000000       1.000000      0.000000      1.100000
# 25%     2016.000000  17357.500000    6322.000000    125.000000     45.600000
# 50%     2018.000000  22299.000000   15369.500000    145.000000     56.500000
# 75%     2019.000000  28706.000000   31982.250000    145.000000     64.200000
# max     2020.000000  65990.000000  259000.000000    580.000000    217.300000
#
#          engineSize
# count  12988.000000
# mean       2.050901
# std        0.532596
# min        0.000000
# 25%        1.675000
# 50%        2.000000
# 75%        2.100000
# max        6.200000

# %%
dataFrame=dataFrame[dataFrame.year != 1970] ## delete 1970s car

# %%
dataFrame=dataFrame.drop("transmission",axis=1)

# %%
dataFrame
# Out:
#        year  price  mileage  tax   mpg  engineSize
# 6177   2019  65990     5076  150  30.4         3.0
# 5779   2020  65990      999  145  28.0         4.0
# 3191   2020  65980     3999  145  28.0         4.0
# 4727   2019  65000     3398  145  27.2         4.0
# 8814   2019  64999      119  145  40.9         3.0
# ...     ...    ...      ...  ...   ...         ...
# 11549  2002   1495    13800  305  39.8         2.7
# 12594  2004   1495   119000  300  34.5         1.8
# 11765  2000   1490    87000  265  27.2         3.2
# 12008  2010   1350   116126  145  54.3         2.0
# 11816  2003    650   109090  235  40.0         1.4
#
# [12987 rows x 6 columns]

# %%
y=dataFrame["price"].values

# %%
x=dataFrame.drop("price",axis=1).values

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=10)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()

# %%
x_train=scaler.fit_transform(x_train)
x_test=scaler.fit_transform(x_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model=Sequential()

model.add(Dense(12,activation="relu"))
model.add(Dense(12,activation="relu"))
model.add(Dense(12,activation="relu"))
model.add(Dense(12,activation="relu"))

model.add(Dense(1))

model.compile(optimizer="adam",loss="mse")

# %%
model.fit(x=x_train,y=y_train,validation_data=(x_test,y_test),batch_size=250,epochs=250)
# Out:
# Epoch 1/250
# 37/37 [==============================] - 1s 5ms/step - loss: 672142080.0000 - val_loss: 688097088.0000
# Epoch 2/250
# 37/37 [==============================] - 0s 2ms/step - loss: 672111808.0000 - val_loss: 688044736.0000
# Epoch 3/250
# 37/37 [==============================] - 0s 2ms/step - loss: 672020032.0000 - val_loss: 687883520.0000
# Epoch 4/250
# 37/37 [==============================] - 0s 2ms/step - loss: 671735232.0000 - val_loss: 687398400.0000
# Epoch 5/250
# 37/37 [==============================] - 0s 2ms/step - loss: 670946496.0000 - val_loss: 686141376.0000
# Epoch 6/250
# 37/37 [==============================] - 0s 2ms/step - loss: 669056768.0000 - val_loss: 683299584.0000
# Epoch 7/250
# 37/37 [==============================] - 0s 2ms/step - loss: 665050432.0000 - val_loss: 677559168.0000
# Epoch 8/250
# 37/37 [==============================] - 0s 2ms/step - loss: 657267136.0000 - val_loss: 666813376.0000
# Epoch 9/250
# ...

# %%
lossData=pd.DataFrame(model.history.history)

# %%
lossData.head(30)
# Out:
#            loss     val_loss
# 0   672142080.0  688097088.0
# 1   672111808.0  688044736.0
# 2   672020032.0  687883520.0
# 3   671735232.0  687398400.0
# 4   670946496.0  686141376.0
# 5   669056768.0  683299584.0
# 6   665050432.0  677559168.0
# 7   657267136.0  666813376.0
# 8   643393920.0  648420928.0
# 9   620603840.0  619307200.0
# 10  585783488.0  576563392.0
# 11  536587552.0  517971904.0
# 12  471830432.0  444306368.0
# 13  393870240.0  359313664.0
# 14  308837312.0  272251776.0
# 15  227405920.0  195298112.0
# 16  160985792.0  139847360.0
# 17  117651440.0  108011072.0
# 18   96402056.0   94795192.0
# 19   88504256.0   90519032.0
# 20   86185640.0   89011440.0
# 21   85274928.0   88209240.0
# 22   84726904.0   87538336.0
# 23   84248112.0   86922464.0
# 24   83812408.0   86339080.0
# 25   83377072.0   85793984.0
# 26   82951448.0   85271712.0
# 27   82546032.0   84731016.0
# 28   82135696.0   84227744.0
# 29   81739184.0   83719024.0

# %%
plt.figure(figsize=(10,8))
lossData.plot()
##two line is down together so my model is true
# Out:
# <AxesSubplot:>

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
estimateData=model.predict(x_test)
# Out:
# 122/122 [==============================] - 0s 582us/step

# %%
estimateData
# Out:
# array([[20708.525],
#        [23028.283],
#        [24091.203],
#        ...,
#        [24651.684],
#        [ 7645.77 ],
#        [23701.926]], dtype=float32)

# %%
mean_absolute_error(y_test,estimateData) ## ı found real price data and my predict data diff
# Out:
# 3456.806479816249

# %%
plt.scatter(y_test,estimateData)

# %%
dataFrame.iloc[2]
# Out:
# year           2020.0
# price         65980.0
# mileage        3999.0
# tax             145.0
# mpg              28.0
# engineSize        4.0
# Name: 3191, dtype: float64

# %%
newCar=dataFrame.drop("price",axis=1).iloc[2]

# %%
newCar
# Out:
# year          2020.0
# mileage       3999.0
# tax            145.0
# mpg             28.0
# engineSize       4.0
# Name: 3191, dtype: float64

# %%
newCar=scaler.transform(newCar.values.reshape(-1,5))

# %%
model.predict(newCar)
# Out:
# 1/1 [==============================] - 0s 16ms/step
# array([[60456.414]], dtype=float32)
